# %%
import pandas as pd

# %%
df = pd.read_csv("D:/AOC/Dataset/labelled_dataset/manifest_samples.tsv", sep="\t")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14093 entries, 0 to 14092
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sample_id                14093 non-null  object
#  1   session_id               14093 non-null  object
#  2   scenario                 14093 non-null  object
#  3   anchor_modality          14093 non-null  object
#  4   anchor_ts                14093 non-null  float64
#  5   meta_path                0 non-null      float64
#  6   calib_intrinsics         0 non-null      float64
#  7   calib_extrinsics         0 non-null      float64
#  8   lidar_path               14093 non-null  object
#  9   has_lidar                14093 non-null  int64
#  10  dt_lidar_ms              0 non-null      float64
#  11  lidar_ann_path           14093 non-null  object
#  12  cam_fish_left_path       13908 non-null  object
#  13  has_cam_fish_left        14093 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['sample_id', 'session_id', 'scenario', 'anchor_modality', 'anchor_ts',
#        'meta_path', 'calib_intrinsics', 'calib_extrinsics', 'lidar_path',
#        'has_lidar', 'dt_lidar_ms', 'lidar_ann_path', 'cam_fish_left_path',
#        'has_cam_fish_left', 'dt_cam_fish_left_ms', 'cam_fish_left_ann_path',
#        'cam_fish_front_path', 'has_cam_fish_front', 'dt_cam_fish_front_ms',
#        'cam_fish_front_ann_path', 'cam_fish_right_path', 'has_cam_fish_right',
#        'dt_cam_fish_right_ms', 'cam_fish_right_ann_path', 'cam_zed_rgb_path',
#        'has_cam_zed_rgb', 'dt_cam_zed_rgb_ms', 'cam_zed_rgb_ann_path',
#        'cam_zed_depth_path', 'has_cam_zed_depth', 'dt_cam_zed_depth_ms',
#        'cam_zed_depth_ann_path'],
#       dtype='object')

# %%
df.head()
# Out:
#                                            sample_id  \
# 0  footpath1_1walk_1stand_st_11_12_2024_1_label_1...
# 1  footpath1_1walk_1stand_st_11_12_2024_1_label_1...
# 2  footpath1_1walk_1stand_st_11_12_2024_1_label_1...
# 3  footpath1_1walk_1stand_st_11_12_2024_1_label_1...
# 4  footpath1_1walk_1stand_st_11_12_2024_1_label_1...
#
#                                      session_id                   scenario  \
# 0  footpath1_1walk_1stand_st_11_12_2024_1_label  footpath1_1walk_1stand_st
# 1  footpath1_1walk_1stand_st_11_12_2024_1_label  footpath1_1walk_1stand_st
# 2  footpath1_1walk_1stand_st_11_12_2024_1_label  footpath1_1walk_1stand_st
# 3  footpath1_1walk_1stand_st_11_12_2024_1_label  footpath1_1walk_1stand_st
# 4  footpath1_1walk_1stand_st_11_12_2024_1_label  footpath1_1walk_1stand_st
#
#   anchor_modality     anchor_ts  meta_path  calib_intrinsics  \
# 0           lidar  1.731409e+09        NaN               NaN
# 1           lidar  1.731409e+09        NaN               NaN
# ...
